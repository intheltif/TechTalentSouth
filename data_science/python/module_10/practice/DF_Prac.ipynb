# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chip = pd.read_csv(url, sep="\t")
chip.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
cols = chip.columns
for col in cols:
    print(col, end=" | ")
# Out:
# order_id | quantity | item_name | choice_description | item_price |

# %%
#df = chip.drop_duplicates().groupby(['item_name', 'choice_description']).count()
df = chip.groupby('item_name')['quantity'].nunique()
type(df)
df2 = pd.DataFrame(df)
# Out:
# item_name  6 Pack Soft Drink  Barbacoa Bowl  Barbacoa Burrito  \
# quantity                   2              1                 1
#
# item_name  Barbacoa Crispy Tacos  Barbacoa Salad Bowl  Barbacoa Soft Tacos  \
# quantity                       2                    1                    1
#
# item_name  Bottled Water  Bowl  Burrito  Canned Soda  Canned Soft Drink  \
# quantity               7     2        1            3                  4
#
# item_name  Carnitas Bowl  Carnitas Burrito  Carnitas Crispy Tacos  \
# quantity               3                 2                      2
#
# item_name  Carnitas Salad  Carnitas Salad Bowl  Carnitas Soft Tacos  \
# quantity                1                    1                    1
#
# item_name  Chicken Bowl  Chicken Burrito  Chicken Crispy Tacos  Chicken Salad  \
# quantity              3                4                     2              1
#
# item_name  Chicken Salad Bowl  Chicken Soft Tacos  Chips  \
# quantity                    2                   2      3
#
# item_name  Chips and Fresh Tomato Salsa  Chips and Guacamole  \
# quantity                              4                    4
#
# item_name  Chips and Mild Fresh Tomato Salsa  \
# quantity                                   1
#
# item_name  Chips and Roasted Chili Corn Salsa  \
# quantity                                    2
#
# item_name  Chips and Roasted Chili-Corn Salsa  \
# quantity                                    1
#
# item_name  Chips and Tomatillo Green Chili Salsa  \
# quantity                                       2
#
# item_name  Chips and Tomatillo Red Chili Salsa  \
# quantity                                     2
#
# item_name  Chips and Tomatillo-Green Chili Salsa  \
# quantity                                       2
#
# item_name  Chips and Tomatillo-Red Chili Salsa  Crispy Tacos  Izze  \
# quantity                                     3             1     1
#
# item_name  Nantucket Nectar  Salad  Side of Chips  Steak Bowl  Steak Burrito  \
# quantity                  2      1              3           3              3
#
# item_name  Steak Crispy Tacos  Steak Salad  Steak Salad Bowl  \
# quantity                    2            1                 2
#
# item_name  Steak Soft Tacos  Veggie Bowl  Veggie Burrito  Veggie Crispy Tacos  \
# quantity                  2            2               2                    1
#
# item_name  Veggie Salad  Veggie Salad Bowl  Veggie Soft Tacos
# quantity              1                  1                  2
